# %%
from typing import Callable, Tuple
from finite_distributions.FiniteDistribution import FiniteDistribution
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sinkhorn.SinkhornRunner as SinkhornRunner
import sinkhorn.SinkhornKernels as skern
import visualizer.joint_distribution_visualizer as jdv
import pandas as pd

# %%
def gaussian_prob(mu: float, sigma: float, x: float):
    return np.exp(-(x - mu)**2 / (2 * sigma * sigma))

# %%
mu_1 = -0.0
sigma_1 = 1.0

mu_2 = 0.0
sigma_2 = np.sqrt(2)

# %%
xs = [round(x, 5) for x in np.linspace(-5, 5, 25)]

# %%
s1 = np.sum([gaussian_prob(mu_1, sigma_1, x) for x in xs])
s2 = np.sum([gaussian_prob(mu_2, sigma_2, x) for x in xs])

dist_1 = FiniteDistribution({x: gaussian_prob(mu_1, sigma_1, x) / s1 for x in xs})
dist_2 = FiniteDistribution({x: gaussian_prob(mu_2, sigma_2, x) / s2 for x in xs})

# %%
c = lambda x, y: (x - y)**2

# %%
def unregularized_transport_map(x: float) -> float:
    return mu_2 + (x - mu_1) * (sigma_2/sigma_1)

# %%
# p-norm
p = 2.
sinkhorn_runner = skern.get_pnorm_regularized_runner(p, c)
# entropic
sinkhorn_runner_entropic = skern.get_entropically_regularized_runner(c)


epsilons = np.power(10.0, np.linspace(-2, 0.0, 50))
delta = 0.025

distribution_outputs_quadratic = {}
for epsilon in epsilons:
    print(f"Running Quadratic, epsilon = {epsilon}")
    pi_p, f_p, g_p, iterations, outer_iterations = sinkhorn_runner.run_sinkhorn(dist_1, dist_2, epsilon, delta)
    distribution_outputs_quadratic[epsilon] = (pi_p, f_p, g_p, iterations, outer_iterations)
    print(f"Done with Quadratic, epsilon = {epsilon}. Inner iterations: {iterations}. Outer iterations: {outer_iterations}")

print("Done with quadratic.")

distribution_outputs_entropic = {}
for epsilon in epsilons:
    print(f"Running Entropic, epsilon = {epsilon}")
    _, _, _, _, iterations_outer_previous = distribution_outputs_quadratic[epsilon]
    pi_p, f_p, g_p, iterations, outer_iterations = sinkhorn_runner_entropic.run_sinkhorn(dist_1, dist_2, epsilon, delta)
    distribution_outputs_entropic[epsilon] = (pi_p, f_p, g_p, iterations, outer_iterations)
    print(f"Done with Entropic, epsilon = {epsilon}. Inner iterations: {iterations}. Outer iterations: {outer_iterations}")

print("Done with entropic.")
# Out:
# Running Quadratic, epsilon = 0.01
# Done with Quadratic, epsilon = 0.01. Inner iterations: 16599. Outer iterations: 24
# Running Quadratic, epsilon = 0.010985411419875584
# Done with Quadratic, epsilon = 0.010985411419875584. Inner iterations: 16645. Outer iterations: 24
# Running Quadratic, epsilon = 0.012067926406393288
# Done with Quadratic, epsilon = 0.012067926406393288. Inner iterations: 15802. Outer iterations: 23
# Running Quadratic, epsilon = 0.013257113655901088
# Done with Quadratic, epsilon = 0.013257113655901088. Inner iterations: 15719. Outer iterations: 23
# Running Quadratic, epsilon = 0.014563484775012436
# Done with Quadratic, epsilon = 0.014563484775012436. Inner iterations: 14882. Outer iterations: 22
# Running Quadratic, epsilon = 0.015998587196060583
# Done with Quadratic, epsilon = 0.015998587196060583. Inner iterations: 14708. Outer iterations: 22
# Running Quadratic, epsilon = 0.017575106248547922
# Done with Quadratic, epsilon = 0.017575106248547922. Inner iterations: 14014. Outer iterations: 21
# Running Quadratic, epsilon = 0.019306977288832496
# Done with Quadratic, epsilon = 0.019306977288832496. Inner iterations: 13442. Outer iterations: 20
# Running Quadratic, epsilon = 0.021209508879201904
# Done with Quadratic, epsilon = 0.021209508879201904. Inner iterations: 12553. Outer iterations: 19
# Running Quadratic, epsilon = 0.023299518105153717
# Done with Quadratic, epsilon = 0.023299518105153717. Inner iterations: 11741. Outer iterations: 18
# Running Quadratic, epsilon = 0.025595479226995357
# Done with Quadratic, epsilon = 0.025595479226995357. Inner iterations: 11056. Outer iterations: 17
# Running Quadratic, epsilon = 0.028117686979742307
# Done with Quadratic, epsilon = 0.028117686979742307. Inner iterations: 11065. Outer iterations: 17
# Running Quadratic, epsilon = 0.030888435964774818
# Done with Quadratic, epsilon = 0.030888435964774818. Inner iterations: 10303. Outer iterations: 16
# Running Quadratic, epsilon = 0.03393221771895328
# Done with Quadratic, epsilon = 0.03393221771895328. Inner iterations: 10354. Outer iterations: 16
# Running Quadratic, epsilon = 0.0372759372031494
# Done with Quadratic, epsilon = 0.0372759372031494. Inner iterations: 9554. Outer iterations: 15
# Running Quadratic, epsilon = 0.040949150623804234
# Done with Quadratic, epsilon = 0.040949150623804234. Inner iterations: 9498. Outer iterations: 15
# Running Quadratic, epsilon = 0.04498432668969444
# Done with Quadratic, epsilon = 0.04498432668969444. Inner iterations: 8697. Outer iterations: 14
# Running Quadratic, epsilon = 0.04941713361323833
# Done with Quadratic, epsilon = 0.04941713361323833. Inner iterations: 8193. Outer iterations: 13
# Running Quadratic, epsilon = 0.054286754393238594
# Done with Quadratic, epsilon = 0.054286754393238594. Inner iterations: 8134. Outer iterations: 13
# Running Quadratic, epsilon = 0.05963623316594643
# Done with Quadratic, epsilon = 0.05963623316594643. Inner iterations: 6807. Outer iterations: 11
# Running Quadratic, epsilon = 0.0655128556859551
# Done with Quadratic, epsilon = 0.0655128556859551. Inner iterations: 5548. Outer iterations: 9
# Running Quadratic, epsilon = 0.07196856730011521
# Done with Quadratic, epsilon = 0.07196856730011521. Inner iterations: 4924. Outer iterations: 8
# Running Quadratic, epsilon = 0.07906043210907697
# Done with Quadratic, epsilon = 0.07906043210907697. Inner iterations: 4314. Outer iterations: 7
# Running Quadratic, epsilon = 0.08685113737513525
# Done with Quadratic, epsilon = 0.08685113737513525. Inner iterations: 4310. Outer iterations: 7
# Running Quadratic, epsilon = 0.09540954763499938
# Done with Quadratic, epsilon = 0.09540954763499938. Inner iterations: 3597. Outer iterations: 6
# Running Quadratic, epsilon = 0.10481131341546858
# Done with Quadratic, epsilon = 0.10481131341546858. Inner iterations: 2997. Outer iterations: 5
# Running Quadratic, epsilon = 0.1151395399326447
# Done with Quadratic, epsilon = 0.1151395399326447. Inner iterations: 3049. Outer iterations: 5
# Running Quadratic, epsilon = 0.12648552168552957
# Done with Quadratic, epsilon = 0.12648552168552957. Inner iterations: 2981. Outer iterations: 5
# Running Quadratic, epsilon = 0.13894954943731375
# Done with Quadratic, epsilon = 0.13894954943731375. Inner iterations: 2412. Outer iterations: 4
# Running Quadratic, epsilon = 0.15264179671752334
# Done with Quadratic, epsilon = 0.15264179671752334. Inner iterations: 2439. Outer iterations: 4
# Running Quadratic, epsilon = 0.16768329368110074
# Done with Quadratic, epsilon = 0.16768329368110074. Inner iterations: 2409. Outer iterations: 4
# Running Quadratic, epsilon = 0.18420699693267154
# Done with Quadratic, epsilon = 0.18420699693267154. Inner iterations: 2355. Outer iterations: 4
# Running Quadratic, epsilon = 0.20235896477251566
# Done with Quadratic, epsilon = 0.20235896477251566. Inner iterations: 2386. Outer iterations: 4
# Running Quadratic, epsilon = 0.22229964825261944
# Done with Quadratic, epsilon = 0.22229964825261944. Inner iterations: 2385. Outer iterations: 4
# Running Quadratic, epsilon = 0.2442053094548651
# Done with Quadratic, epsilon = 0.2442053094548651. Inner iterations: 1812. Outer iterations: 3
# Running Quadratic, epsilon = 0.2682695795279725
# Done with Quadratic, epsilon = 0.2682695795279725. Inner iterations: 1751. Outer iterations: 3
# Running Quadratic, epsilon = 0.29470517025518095
# Done with Quadratic, epsilon = 0.29470517025518095. Inner iterations: 1761. Outer iterations: 3
# Running Quadratic, epsilon = 0.32374575428176433
# Done with Quadratic, epsilon = 0.32374575428176433. Inner iterations: 1202. Outer iterations: 2
# Running Quadratic, epsilon = 0.35564803062231287
# Done with Quadratic, epsilon = 0.35564803062231287. Inner iterations: 1215. Outer iterations: 2
# Running Quadratic, epsilon = 0.3906939937054615
# Done with Quadratic, epsilon = 0.3906939937054615. Inner iterations: 1167. Outer iterations: 2
# Running Quadratic, epsilon = 0.42919342601287763
# Done with Quadratic, epsilon = 0.42919342601287763. Inner iterations: 1222. Outer iterations: 2
# Running Quadratic, epsilon = 0.47148663634573923
# Done with Quadratic, epsilon = 0.47148663634573923. Inner iterations: 1245. Outer iterations: 2
# Running Quadratic, epsilon = 0.517947467923121
# Done with Quadratic, epsilon = 0.517947467923121. Inner iterations: 598. Outer iterations: 1
# Running Quadratic, epsilon = 0.5689866029018296
# Done with Quadratic, epsilon = 0.5689866029018296. Inner iterations: 624. Outer iterations: 1
# Running Quadratic, epsilon = 0.6250551925273969
# Done with Quadratic, epsilon = 0.6250551925273969. Inner iterations: 595. Outer iterations: 1
# Running Quadratic, epsilon = 0.6866488450042998
# Done with Quadratic, epsilon = 0.6866488450042998. Inner iterations: 605. Outer iterations: 1
# Running Quadratic, epsilon = 0.7543120063354615
# Done with Quadratic, epsilon = 0.7543120063354615. Inner iterations: 634. Outer iterations: 1
# Running Quadratic, epsilon = 0.8286427728546842
# Done with Quadratic, epsilon = 0.8286427728546842. Inner iterations: 586. Outer iterations: 1
# Running Quadratic, epsilon = 0.9102981779915218
# Done with Quadratic, epsilon = 0.9102981779915218. Inner iterations: 627. Outer iterations: 1
# Running Quadratic, epsilon = 1.0
# Done with Quadratic, epsilon = 1.0. Inner iterations: 610. Outer iterations: 1
# Done with quadratic.
# Running Entropic, epsilon = 0.01
# Done with Entropic, epsilon = 0.01. Inner iterations: 271296. Outer iterations: 298
# Running Entropic, epsilon = 0.010985411419875584
# Done with Entropic, epsilon = 0.010985411419875584. Inner iterations: 248229. Outer iterations: 274
# Running Entropic, epsilon = 0.012067926406393288
# Done with Entropic, epsilon = 0.012067926406393288. Inner iterations: 224631. Outer iterations: 251
# Running Entropic, epsilon = 0.013257113655901088
# Done with Entropic, epsilon = 0.013257113655901088. Inner iterations: 204840. Outer iterations: 230
# Running Entropic, epsilon = 0.014563484775012436
# Done with Entropic, epsilon = 0.014563484775012436. Inner iterations: 187648. Outer iterations: 212
# Running Entropic, epsilon = 0.015998587196060583
# Done with Entropic, epsilon = 0.015998587196060583. Inner iterations: 170139. Outer iterations: 194
# Running Entropic, epsilon = 0.017575106248547922
# Done with Entropic, epsilon = 0.017575106248547922. Inner iterations: 156090. Outer iterations: 179
# Running Entropic, epsilon = 0.019306977288832496
# Done with Entropic, epsilon = 0.019306977288832496. Inner iterations: 143047. Outer iterations: 165
# Running Entropic, epsilon = 0.021209508879201904
# Done with Entropic, epsilon = 0.021209508879201904. Inner iterations: 130442. Outer iterations: 152
# Running Entropic, epsilon = 0.023299518105153717
# Done with Entropic, epsilon = 0.023299518105153717. Inner iterations: 120089. Outer iterations: 141
# Running Entropic, epsilon = 0.025595479226995357
# Done with Entropic, epsilon = 0.025595479226995357. Inner iterations: 110101. Outer iterations: 130
# Running Entropic, epsilon = 0.028117686979742307
# Done with Entropic, epsilon = 0.028117686979742307. Inner iterations: 101852. Outer iterations: 121
# Running Entropic, epsilon = 0.030888435964774818
# Done with Entropic, epsilon = 0.030888435964774818. Inner iterations: 93456. Outer iterations: 112
# Running Entropic, epsilon = 0.03393221771895328
# Done with Entropic, epsilon = 0.03393221771895328. Inner iterations: 86309. Outer iterations: 104
# Running Entropic, epsilon = 0.0372759372031494
# Done with Entropic, epsilon = 0.0372759372031494. Inner iterations: 80146. Outer iterations: 97
# Running Entropic, epsilon = 0.040949150623804234
# Done with Entropic, epsilon = 0.040949150623804234. Inner iterations: 72978. Outer iterations: 89
# Running Entropic, epsilon = 0.04498432668969444
# Done with Entropic, epsilon = 0.04498432668969444. Inner iterations: 66655. Outer iterations: 82
# Running Entropic, epsilon = 0.04941713361323833
# Done with Entropic, epsilon = 0.04941713361323833. Inner iterations: 60544. Outer iterations: 75
# Running Entropic, epsilon = 0.054286754393238594
# Done with Entropic, epsilon = 0.054286754393238594. Inner iterations: 55267. Outer iterations: 69
# Running Entropic, epsilon = 0.05963623316594643
# Done with Entropic, epsilon = 0.05963623316594643. Inner iterations: 49024. Outer iterations: 62
# Running Entropic, epsilon = 0.0655128556859551
# Done with Entropic, epsilon = 0.0655128556859551. Inner iterations: 43902. Outer iterations: 56
# Running Entropic, epsilon = 0.07196856730011521
# Done with Entropic, epsilon = 0.07196856730011521. Inner iterations: 39788. Outer iterations: 51
# Running Entropic, epsilon = 0.07906043210907697
# Done with Entropic, epsilon = 0.07906043210907697. Inner iterations: 35525. Outer iterations: 46
# Running Entropic, epsilon = 0.08685113737513525
# Done with Entropic, epsilon = 0.08685113737513525. Inner iterations: 32419. Outer iterations: 42
# Running Entropic, epsilon = 0.09540954763499938
# Done with Entropic, epsilon = 0.09540954763499938. Inner iterations: 29028. Outer iterations: 38
# Running Entropic, epsilon = 0.10481131341546858
# Done with Entropic, epsilon = 0.10481131341546858. Inner iterations: 25739. Outer iterations: 34
# Running Entropic, epsilon = 0.1151395399326447
# Done with Entropic, epsilon = 0.1151395399326447. Inner iterations: 23171. Outer iterations: 31
# Running Entropic, epsilon = 0.12648552168552957
# Done with Entropic, epsilon = 0.12648552168552957. Inner iterations: 21550. Outer iterations: 29
# Running Entropic, epsilon = 0.13894954943731375
# Done with Entropic, epsilon = 0.13894954943731375. Inner iterations: 19306. Outer iterations: 26
# Running Entropic, epsilon = 0.15264179671752334
# Done with Entropic, epsilon = 0.15264179671752334. Inner iterations: 16923. Outer iterations: 23
# Running Entropic, epsilon = 0.16768329368110074
# Done with Entropic, epsilon = 0.16768329368110074. Inner iterations: 15239. Outer iterations: 21
# Running Entropic, epsilon = 0.18420699693267154
# Done with Entropic, epsilon = 0.18420699693267154. Inner iterations: 13655. Outer iterations: 19
# Running Entropic, epsilon = 0.20235896477251566
# Done with Entropic, epsilon = 0.20235896477251566. Inner iterations: 12795. Outer iterations: 18
# Running Entropic, epsilon = 0.22229964825261944
# Done with Entropic, epsilon = 0.22229964825261944. Inner iterations: 11241. Outer iterations: 16
# Running Entropic, epsilon = 0.2442053094548651
# Done with Entropic, epsilon = 0.2442053094548651. Inner iterations: 9885. Outer iterations: 14
# Running Entropic, epsilon = 0.2682695795279725
# Done with Entropic, epsilon = 0.2682695795279725. Inner iterations: 9062. Outer iterations: 13
# Running Entropic, epsilon = 0.29470517025518095
# Done with Entropic, epsilon = 0.29470517025518095. Inner iterations: 8326. Outer iterations: 12
# Running Entropic, epsilon = 0.32374575428176433
# Done with Entropic, epsilon = 0.32374575428176433. Inner iterations: 7601. Outer iterations: 11
# Running Entropic, epsilon = 0.35564803062231287
# Done with Entropic, epsilon = 0.35564803062231287. Inner iterations: 6834. Outer iterations: 10
# Running Entropic, epsilon = 0.3906939937054615
# Done with Entropic, epsilon = 0.3906939937054615. Inner iterations: 6091. Outer iterations: 9
# Running Entropic, epsilon = 0.42919342601287763
# Done with Entropic, epsilon = 0.42919342601287763. Inner iterations: 5398. Outer iterations: 8
# Running Entropic, epsilon = 0.47148663634573923
# Done with Entropic, epsilon = 0.47148663634573923. Inner iterations: 4642. Outer iterations: 7
# Running Entropic, epsilon = 0.517947467923121
# Done with Entropic, epsilon = 0.517947467923121. Inner iterations: 3907. Outer iterations: 6
# Running Entropic, epsilon = 0.5689866029018296
# Done with Entropic, epsilon = 0.5689866029018296. Inner iterations: 4008. Outer iterations: 6
# Running Entropic, epsilon = 0.6250551925273969
# Done with Entropic, epsilon = 0.6250551925273969. Inner iterations: 3212. Outer iterations: 5
# Running Entropic, epsilon = 0.6866488450042998
# Done with Entropic, epsilon = 0.6866488450042998. Inner iterations: 3243. Outer iterations: 5
# Running Entropic, epsilon = 0.7543120063354615
# Done with Entropic, epsilon = 0.7543120063354615. Inner iterations: 2605. Outer iterations: 4
# Running Entropic, epsilon = 0.8286427728546842
# Done with Entropic, epsilon = 0.8286427728546842. Inner iterations: 2633. Outer iterations: 4
# Running Entropic, epsilon = 0.9102981779915218
# Done with Entropic, epsilon = 0.9102981779915218. Inner iterations: 1906. Outer iterations: 3
# Running Entropic, epsilon = 1.0
# Done with Entropic, epsilon = 1.0. Inner iterations: 1878. Outer iterations: 3
# Done with entropic.

# %%
plt.figure()
xs = -np.log10(epsilons)
ys_q = np.log10(np.array([distribution_outputs_quadratic[epsilon][4] for epsilon in epsilons]))
ys_e = np.log10(np.array([distribution_outputs_entropic[epsilon][4] for epsilon in epsilons]))
var_x = np.mean(xs*xs) - np.mean(xs)**2
cov_q = np.mean(ys_q * xs) - np.mean(ys_q)*np.mean(xs)
cov_e = np.mean(ys_e * xs) - np.mean(ys_e)*np.mean(xs)
beta_q = cov_q / var_x
beta_e = cov_e / var_x
plt.plot(xs, ys_q, label = f"quadratic, beta = {beta_q}")
plt.plot(xs, ys_e, label = f"entropic, beta = {beta_e}")
plt.xlabel("Log10(Epsilon^{-1})")
plt.ylabel("Log10(Outer Iterations)")
plt.title("Outer Iterations vs Epsilon")
plt.legend()
plt.show()

# %%
# p-norm
p = 2.
sinkhorn_runner = skern.get_pnorm_regularized_runner(p, c)
# entropic
sinkhorn_runner_entropic = skern.get_entropically_regularized_runner(c)


epsilons = np.power(10.0, np.linspace(-2, -1.2, 15))
delta = 0.025

distribution_outputs_quadratic_smalleps = {}
for epsilon in epsilons:
    print(f"Running Quadratic, epsilon = {epsilon}")
    pi_p, f_p, g_p, iterations, outer_iterations = sinkhorn_runner.run_sinkhorn(dist_1, dist_2, epsilon, delta)
    distribution_outputs_quadratic_smalleps[epsilon] = (pi_p, f_p, g_p, iterations, outer_iterations)
    print(f"Done with Quadratic, epsilon = {epsilon}. Inner iterations: {iterations}. Outer iterations: {outer_iterations}")

print("Done with quadratic.")

distribution_outputs_entropic_smalleps = {}
for epsilon in epsilons:
    print(f"Running Entropic, epsilon = {epsilon}")
    pi_p, f_p, g_p, iterations, outer_iterations = sinkhorn_runner_entropic.run_sinkhorn(dist_1, dist_2, epsilon, delta)
    distribution_outputs_entropic_smalleps[epsilon] = (pi_p, f_p, g_p, iterations, outer_iterations)
    print(f"Done with Entropic, epsilon = {epsilon}. Inner iterations: {iterations}. Outer iterations: {outer_iterations}")

print("Done with entropic.")
# Out:
# Running Quadratic, epsilon = 0.01
# Done with Quadratic, epsilon = 0.01. Inner iterations: 16599. Outer iterations: 24
# Running Quadratic, epsilon = 0.01140624923851321
# Done with Quadratic, epsilon = 0.01140624923851321. Inner iterations: 15825. Outer iterations: 23
# Running Quadratic, epsilon = 0.013010252169108316
# Done with Quadratic, epsilon = 0.013010252169108316. Inner iterations: 15769. Outer iterations: 23
# Running Quadratic, epsilon = 0.014839817889675654
# Done with Quadratic, epsilon = 0.014839817889675654. Inner iterations: 14896. Outer iterations: 22
# Running Quadratic, epsilon = 0.01692666615037876
# Done with Quadratic, epsilon = 0.01692666615037876. Inner iterations: 14129. Outer iterations: 21
# Running Quadratic, epsilon = 0.019306977288832506
# Done with Quadratic, epsilon = 0.019306977288832506. Inner iterations: 13442. Outer iterations: 20
# Running Quadratic, epsilon = 0.022022019499873757
# Done with Quadratic, epsilon = 0.022022019499873757. Inner iterations: 12558. Outer iterations: 19
# Running Quadratic, epsilon = 0.025118864315095794
# Done with Quadratic, epsilon = 0.025118864315095794. Inner iterations: 11273. Outer iterations: 17
# Running Quadratic, epsilon = 0.028651202696637817
# Done with Quadratic, epsilon = 0.028651202696637817. Inner iterations: 10974. Outer iterations: 17
# Running Quadratic, epsilon = 0.03268027589410125
# Done with Quadratic, epsilon = 0.03268027589410125. Inner iterations: 10231. Outer iterations: 16
# Running Quadratic, epsilon = 0.037275937203149416
# Done with Quadratic, epsilon = 0.037275937203149416. Inner iterations: 9554. Outer iterations: 15
# Running Quadratic, epsilon = 0.0425178630338289
# Done with Quadratic, epsilon = 0.0425178630338289. Inner iterations: 8944. Outer iterations: 14
# Running Quadratic, epsilon = 0.048496934285281984
# Done with Quadratic, epsilon = 0.048496934285281984. Inner iterations: 8108. Outer iterations: 13
# Running Quadratic, epsilon = 0.05531681197617227
# Done with Quadratic, epsilon = 0.05531681197617227. Inner iterations: 7478. Outer iterations: 12
# Running Quadratic, epsilon = 0.06309573444801933
# Done with Quadratic, epsilon = 0.06309573444801933. Inner iterations: 6239. Outer iterations: 10
# Done with quadratic.
# Running Entropic, epsilon = 0.01
# Done with Entropic, epsilon = 0.01. Inner iterations: 271296. Outer iterations: 298
# Running Entropic, epsilon = 0.01140624923851321
# Done with Entropic, epsilon = 0.01140624923851321. Inner iterations: 238121. Outer iterations: 264
# Running Entropic, epsilon = 0.013010252169108316
# Done with Entropic, epsilon = 0.013010252169108316. Inner iterations: 209137. Outer iterations: 234
# Running Entropic, epsilon = 0.014839817889675654
# Done with Entropic, epsilon = 0.014839817889675654. Inner iterations: 183390. Outer iterations: 208
# Running Entropic, epsilon = 0.01692666615037876
# Done with Entropic, epsilon = 0.01692666615037876. Inner iterations: 160953. Outer iterations: 185
# Running Entropic, epsilon = 0.019306977288832506
# Done with Entropic, epsilon = 0.019306977288832506. Inner iterations: 143047. Outer iterations: 165
# Running Entropic, epsilon = 0.022022019499873757
# Done with Entropic, epsilon = 0.022022019499873757. Inner iterations: 126922. Outer iterations: 148
# Running Entropic, epsilon = 0.025118864315095794
# Done with Entropic, epsilon = 0.025118864315095794. Inner iterations: 111808. Outer iterations: 132
# Running Entropic, epsilon = 0.028651202696637817
# Done with Entropic, epsilon = 0.028651202696637817. Inner iterations: 100173. Outer iterations: 119
# Running Entropic, epsilon = 0.03268027589410125
# Done with Entropic, epsilon = 0.03268027589410125. Inner iterations: 89009. Outer iterations: 107
# Running Entropic, epsilon = 0.037275937203149416
# Done with Entropic, epsilon = 0.037275937203149416. Inner iterations: 80146. Outer iterations: 97
# Running Entropic, epsilon = 0.0425178630338289
# Done with Entropic, epsilon = 0.0425178630338289. Inner iterations: 70296. Outer iterations: 86
# Running Entropic, epsilon = 0.048496934285281984
# Done with Entropic, epsilon = 0.048496934285281984. Inner iterations: 62279. Outer iterations: 77
# Running Entropic, epsilon = 0.05531681197617227
# Done with Entropic, epsilon = 0.05531681197617227. Inner iterations: 53882. Outer iterations: 67
# Running Entropic, epsilon = 0.06309573444801933
# Done with Entropic, epsilon = 0.06309573444801933. Inner iterations: 46681. Outer iterations: 59
# Done with entropic.

# %%
plt.figure()
xs = -np.log10(np.array(sorted(list(distribution_outputs_entropic_smalleps.keys()))))
ys_q = np.log10(np.array([distribution_outputs_quadratic_smalleps[epsilon][4] for epsilon in epsilons]))
ys_e = np.log10(np.array([distribution_outputs_entropic_smalleps[epsilon][4] for epsilon in epsilons]))
var_x = np.mean(xs*xs) - np.mean(xs)**2
cov_q = np.mean(ys_q * xs) - np.mean(ys_q)*np.mean(xs)
cov_e = np.mean(ys_e * xs) - np.mean(ys_e)*np.mean(xs)
beta_q = cov_q / var_x
beta_e = cov_e / var_x
plt.plot(xs, ys_q, label = f"quadratic, beta = %.2f"%beta_q)
plt.plot(xs, ys_e, label = f"entropic, beta = %.2f"%beta_e)
plt.xlabel("Log10(Epsilon^{-1})")
plt.ylabel("Log10(Outer Iterations)")
plt.title(f"Outer Iterations vs Epsilon [Epsilon <= %.2f]"%np.power(10, -1.2))
plt.legend()
plt.show()

# %%
# now we calculate the maxmimum width of support around each point. 
epsilon_threshold_entropic = 1e-6 # cutoff, since entropic has full support
deminimis = 1e-12 # floating-point rouding cutoff
max_diams_quadratic = []
max_diams_entropic = []
for epsilon in epsilons:
    (pi_q, _, _, _, _) = distribution_outputs_quadratic[epsilon]
    (pi_e, _, _, _, _) = distribution_outputs_entropic[epsilon]
    max_quadratic = 0.0
    max_entropic = 0.0
    for x in dist_1.get_keys():
        maxmin_quadratic = [np.inf, -np.inf]
        maxmin_entropic = [np.inf, -np.inf]
        for y in dist_2.get_keys():
            if pi_q.get_probability((x, y)) > deminimis:
                maxmin_quadratic = [
                    np.min([maxmin_quadratic[0], y]),
                    np.max([maxmin_quadratic[1], y])
                ]
            if pi_e.get_probability((x, y)) > epsilon_threshold_entropic:
                maxmin_entropic = [
                    np.min([maxmin_entropic[0], y]),
                    np.max([maxmin_entropic[1], y])
                ]
        if maxmin_quadratic[0] < maxmin_quadratic[1]:
            max_quadratic = np.max([max_quadratic, maxmin_quadratic[1] - maxmin_quadratic[0]])
        if maxmin_entropic[0] < maxmin_entropic[1]:
            max_entropic = np.max([max_entropic, maxmin_entropic[1] - maxmin_entropic[0]])
    max_diams_quadratic.append(max_quadratic)
    max_diams_entropic.append(max_entropic)

# %%
plt.figure()
xs = -np.log10(epsilons)
ys_q = np.log10(max_diams_quadratic)
ys_e = np.log10(max_diams_entropic)
var_x = np.mean(xs*xs) - np.mean(xs)**2
cov_q = np.mean(ys_q * xs) - np.mean(ys_q)*np.mean(xs)
cov_e = np.mean(ys_e * xs) - np.mean(ys_e)*np.mean(xs)
beta_q = cov_q / var_x
beta_e = cov_e / var_x
plt.plot(-np.log10(epsilons), np.log10(max_diams_quadratic), label='max diams quadratic, beta = %.2f'%beta_q)
plt.plot(-np.log10(epsilons), np.log10(max_diams_entropic), label='max diams entropic, beta = %.2f'%beta_e)
plt.xlabel('epsilon')
plt.ylabel('max diameter')
plt.title('max diameter vs epsilon. Entropic Cutoff = 10e-%.1f'%(-np.log10(epsilon_threshold_entropic)))
plt.legend()
plt.show()
